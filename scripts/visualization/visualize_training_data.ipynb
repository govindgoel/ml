# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV files
df_loss = pd.read_csv('val_loss.csv')
df_train_loss = pd.read_csv('train_loss.csv')
df_r = pd.read_csv('r2.csv')
df_lr = pd.read_csv('lr.csv')

run_name = 'wannabe_best_6'

# %%
df_lr.columns
# Out:
# Index(['epoch', 'wannabe_best_6 - _step', 'wannabe_best_6 - _step__MIN',
#        'wannabe_best_6 - _step__MAX', 'wannabe_best_6 - lr',
#        'wannabe_best_6 - lr__MIN', 'wannabe_best_6 - lr__MAX'],
#       dtype='object')

# %%
# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Plotting the loss with x-axis starting from 0
plt.plot(df_lr['epoch'], df_lr[run_name + ' - lr'], label='Learning rate', color = 'pink')

# Set x-axis limits to start from 0
plt.xlim(left=0)
plt.xlim(right=900)

# plt.ylim(bottom=0)

# Add labels and title
plt.xlabel('Epoch')
plt.ylabel('Learning rate', color = 'pink')
plt.legend()

# Customize the y-axis color
plt.tick_params(axis='y', colors='pink')  # Change tick color
plt.gca().yaxis.label.set_color('pink')   # Change y-axis label color
plt.gca().spines['left'].set_color('pink') # Change the color of the y-axis spine (left spine)

# Save the figure
plt.savefig('lr.png', dpi=500, bbox_inches='tight')  # Save as a high-resolution image

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot the loss with x-axis starting from 0
ax1.plot(df_loss['epoch'], df_loss[run_name + ' - val_loss'], label='Validation loss', color='b')
ax1.plot(df_train_loss['epoch'], df_train_loss[run_name + ' - train_loss'], label='Training loss', color='r')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Validation loss', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create a secondary y-axis
# ax2 = ax1.twinx()
# ax2.plot(df_r['epoch'], df_r[run_name + ' - r^2'], label=r"$R^2$", color='g')
# ax2.set_ylabel(r"$R^2$", color='g')
# ax2.set_ylim(0, 0.5)  # Set y-axis limits for R squared
# ax2.tick_params(axis='y', labelcolor='g')

plt.xlim(left=0)
plt.xlim(right=800)
# plt.ylim(bottom=0)
# Add legends
fig.legend(loc='upper right', bbox_to_anchor=(0.85, 0.85))

# Save the figure
plt.savefig('loss_plot.png', dpi=500, bbox_inches='tight')  # Save as a high-resolution image

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Create a figure with two subplots side by side
fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(16, 6), sharey=False)

# Plot for Learning Rate
ax1.plot(df_lr['epoch'], df_lr[run_name + ' - lr'], label='Learning rate', color='pink')
ax1.set_xlim(0, 900)
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Learning rate', color='pink')
ax1.tick_params(axis='y', labelcolor='pink')
ax1.spines['left'].set_color('pink')  # Change the color of the y-axis spine

# Plot for Validation Loss and R^2
# Plot the loss with x-axis starting from 0
ax2 = ax3.twinx()  # Create a secondary y-axis for R^2
ax3.plot(df_loss['epoch'], df_loss[run_name + ' - test_loss'], label='Validation loss', color='b')
ax3.set_xlabel('Epoch')
ax3.set_ylabel('Validation loss', color='b')
ax3.tick_params(axis='y', labelcolor='b')

ax2.plot(df_r['epoch'], df_r[run_name + ' - r^2'], label=r"$R^2$", color='g')
ax2.set_ylabel(r"$R^2$", color='g')
ax2.set_ylim(0, 0.5)  # Set y-axis limits for R squared
ax2.tick_params(axis='y', labelcolor='g')

# Set x-axis limits
ax3.set_xlim(0, 900)

# Add legends
fig.legend(loc='upper right', bbox_to_anchor=(1, 1), bbox_transform=plt.gcf().transFigure)

# Save the figure
plt.tight_layout()  # Adjust the layout
plt.savefig('combined_plot.png', dpi=500, bbox_inches='tight')  # Save as a high-resolution image

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/chenhao-gnn/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'wannabe_best_6 - test_loss'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 21
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6), sharey=False)

# Plot for Validation Loss and R^2 on the left
ax1.plot(df_loss['epoch'], df_loss['dazzling-wildflower-18 - test_loss'], label='Validation loss', color='b')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Validation loss', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create a secondary y-axis for R^2
ax1_twin = ax1.twinx()
ax1_twin.plot(df_r['epoch'], df_r['dazzling-wildflower-18 - r^2'], label=r"$R^2$", color='g')
ax1_twin.set_ylabel(r"$R^2$", color='g')
ax1_twin.set_ylim(0, 0.5)  # Set y-axis limits for R squared
ax1_twin.tick_params(axis='y', labelcolor='g')

# Set x-axis limits
ax1.set_xlim(0, 900)

# Plot for Learning Rate on the right
ax2.plot(df_lr['epoch'], df_lr['dazzling-wildflower-18 - lr'], label='Learning rate', color='pink')
ax2.set_xlim(0, 900)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Learning rate', color='pink')
ax2.tick_params(axis='y', labelcolor='pink')
ax2.spines['left'].set_color('pink')  # Change the color of the y-axis spine

# Add legends
fig.legend(loc='upper right', bbox_to_anchor=(1, 1), bbox_transform=plt.gcf().transFigure)

# Save the figure
plt.tight_layout()  # Adjust the layout
plt.savefig('combined_plot.png', dpi=500, bbox_inches='tight')  # Save as a high-resolution image

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/chenhao-gnn/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dazzling-wildflower-18 - test_loss'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 11
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6), sharey=False)

# Plot for Validation Loss and R^2 on the left
line1 = ax1.plot(df_loss['epoch'], df_loss[run_name + ' - val_loss'], label='Validation loss', color='b')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Validation loss', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create a secondary y-axis for R^2
ax1_twin = ax1.twinx()
line2 = ax1_twin.plot(df_r['epoch'], df_r[run_name + ' - r^2'], label=r"$R^2$", color='g')
ax1_twin.set_ylabel(r"$R^2$", color='g')
ax1_twin.set_ylim(0, 0.5)  # Set y-axis limits for R squared
ax1_twin.tick_params(axis='y', labelcolor='g')

# Combine handles and labels for a single legend
lines = line1 + line2
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper right')

# Set x-axis limits
ax1.set_xlim(0, 900)

# Plot for Learning Rate on the right
ax2.plot(df_lr['epoch'], df_lr[run_name + ' - lr'], label='Learning rate', color='purple')
ax2.set_xlim(0, 900)
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Learning rate', color='purple')
ax2.tick_params(axis='y', labelcolor='purple')
ax2.spines['left'].set_color('purple')  # Change the color of the y-axis spine

# Add legend to the right plot
ax2.legend(loc='upper right')

# Save the figure
plt.tight_layout()  # Adjust the layout
plt.savefig('combined_plot.png', dpi=500, bbox_inches='tight')  # Save as a high-resolution image

# Show the plot
plt.show()

# %% [markdown]
# ## Most Recent Model !

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV files
df_val_loss = pd.read_csv('val_loss.csv')
df_r2 = pd.read_csv('r2.csv')
df_spearman = pd.read_csv('spearman.csv')
df_pearson = pd.read_csv('pearson.csv')

# %%
df_val_loss.columns
# Out:
# Index(['epoch', 'wannabe_best_6 - _step', 'wannabe_best_6 - _step__MIN',
#        'wannabe_best_6 - _step__MAX', 'wannabe_best_6 - val_loss',
#        'wannabe_best_6 - val_loss__MIN', 'wannabe_best_6 - val_loss__MAX'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

epoch_steps = range(750)

# Plot the loss with x-axis starting from 0
ax1.plot(epoch_steps, df_train_loss[run_name + ' - train_loss'], label='Training loss', color='r')
ax1.plot(epoch_steps, df_val_loss[run_name + ' - val_loss'], label='Validation loss', color='b')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Validation loss', color='b')
ax1.tick_params(axis='y', labelcolor='b')

# Create a secondary y-axis
ax2 = ax1.twinx()
ax2.plot(epoch_steps, df_r2[run_name + ' - r^2'], label=r"$R^2$", color='g')
ax2.set_ylabel(r"$R^2$", color='g')
ax2.set_ylim(0, 0.8)  # Set y-axis limits for R squared
ax2.tick_params(axis='y', labelcolor='g')

plt.xlim(left=0)
plt.xlim(right=800)
# plt.ylim(bottom=0)
# Add legends
fig.legend(loc='upper right', bbox_to_anchor=(0.8, 0.8))

# Save the figure
plt.savefig('loss_plot.png', dpi=500, bbox_inches='tight')  # Save as a high-resolution image

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(10, 6))

epoch_steps = range(750)

# Plot the loss with x-axis starting from 0
ax1.plot(epoch_steps, df_pearson['wannabe_best_6 - pearson'], label='Pearson', color='firebrick')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Pearson', color='firebrick')
ax1.set_ylim(0, 0.9)  # Moved Pearson limits to primary axis
ax1.tick_params(axis='y', labelcolor='firebrick')

# Create a secondary y-axis
ax2 = ax1.twinx()
ax2.plot(epoch_steps, df_spearman['wannabe_best_6 - spearman'], label='Spearman', color='mediumslateblue')
ax2.set_ylabel('Spearman', color='mediumslateblue')
ax2.set_ylim(0, 0.5)  # Moved Spearman limits to secondary axis
ax2.tick_params(axis='y', labelcolor='mediumslateblue')


plt.xlim(left=0)
plt.xlim(right=800)
# plt.ylim(bottom=0)
# Add legends
fig.legend(loc='upper right', bbox_to_anchor=(0.85, 0.8))

# Save the figure
plt.savefig('pearson_spearman.png', dpi=500, bbox_inches='tight')  # Save as a high-resolution image

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Set the font to Times New Roman
plt.rcParams['font.family'] = 'Times New Roman'

# Create sample data
x = [1, 2, 3, 4, 5]
y = [2, 4, 3, 5, 4]

# Create subplots for different color combinations
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 8))
fig.suptitle('Color Combination Options', fontsize=14)

# Option 1: darkred/purple (current)
ax1.plot(x, y, color='darkred', label='Pearson', linewidth=2)
ax1.plot(x, y, color='purple', label='Spearman', linewidth=2)
ax1.set_title('darkred/purple')
ax1.legend()

# Option 2: crimson/indigo
ax2.plot(x, y, color='crimson', label='Pearson', linewidth=2)
ax2.plot(x, y, color='indigo', label='Spearman', linewidth=2)
ax2.set_title('crimson/indigo')
ax2.legend()

# Option 3: maroon/blueviolet
ax3.plot(x, y, color='maroon', label='Pearson', linewidth=2)
ax3.plot(x, y, color='blueviolet', label='Spearman', linewidth=2)
ax3.set_title('maroon/blueviolet')
ax3.legend()

# Option 4: firebrick/mediumslateblue
ax4.plot(x, y, color='firebrick', label='Pearson', linewidth=2)
ax4.plot(x, y, color='mediumslateblue', label='Spearman', linewidth=2)
ax4.set_title('firebrick/mediumslateblue')
ax4.legend()

plt.tight_layout()
plt.show()
